# %%
# !pip install fastapi uvicorn pymongo python-jose[cryptography] bcrypt pyngrok nest_asyncio
# Out:
# Requirement already satisfied: fastapi in d:\full machine learning\lib\site-packages (0.115.12)
# Requirement already satisfied: uvicorn in d:\full machine learning\lib\site-packages (0.34.2)
# Requirement already satisfied: pymongo in d:\full machine learning\lib\site-packages (4.13.0)
# Requirement already satisfied: bcrypt in d:\full machine learning\lib\site-packages (3.2.0)
# Requirement already satisfied: pyngrok in d:\full machine learning\lib\site-packages (7.2.9)
# Requirement already satisfied: nest_asyncio in d:\full machine learning\lib\site-packages (1.6.0)
# Requirement already satisfied: python-jose[cryptography] in d:\full machine learning\lib\site-packages (3.5.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in d:\full machine learning\lib\site-packages (from fastapi) (0.46.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in d:\full machine learning\lib\site-packages (from fastapi) (1.10.12)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\full machine learning\lib\site-packages (from fastapi) (4.9.0)
# Requirement already satisfied: click>=7.0 in d:\full machine learning\lib\site-packages (from uvicorn) (8.1.7)
# Requirement already satisfied: h11>=0.8 in d:\full machine learning\lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in d:\full machine learning\lib\site-packages (from pymongo) (2.7.0)
# Requirement already satisfied: ecdsa!=0.15 in d:\full machine learning\lib\site-packages (from python-jose[cryptography]) (0.19.1)
# Requirement already satisfied: rsa!=4.1.1,!=4.4,<5.0,>=4.0 in d:\full machine learning\lib\site-packages (from python-jose[cryptography]) (4.9.1)
# Requirement already satisfied: pyasn1>=0.5.0 in d:\full machine learning\lib\site-packages (from python-jose[cryptography]) (0.6.1)
# Requirement already satisfied: cryptography>=3.4.0 in d:\full machine learning\lib\site-packages (from python-jose[cryptography]) (42.0.2)
# Requirement already satisfied: cffi>=1.1 in d:\full machine learning\lib\site-packages (from bcrypt) (1.16.0)
# Requirement already satisfied: six>=1.4.1 in d:\full machine learning\lib\site-packages (from bcrypt) (1.16.0)
# Requirement already satisfied: PyYAML>=5.1 in d:\full machine learning\lib\site-packages (from pyngrok) (6.0.1)
# Requirement already satisfied: pycparser in d:\full machine learning\lib\site-packages (from cffi>=1.1->bcrypt) (2.21)
# Requirement already satisfied: colorama in d:\full machine learning\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Requirement already satisfied: anyio<5,>=3.6.2 in d:\full machine learning\lib\site-packages (from starlette<0.47.0,>=0.40.0->fastapi) (4.2.0)
# Requirement already satisfied: idna>=2.8 in d:\full machine learning\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi) (3.4)
# Requirement already satisfied: sniffio>=1.1 in d:\full machine learning\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi) (1.3.0)

# %%
# !pip install python-multipart
# Out:
# Requirement already satisfied: python-multipart in d:\full machine learning\lib\site-packages (0.0.20)

# %%
# main.py

from fastapi import FastAPI, Depends, HTTPException
from fastapi.security import OAuth2PasswordBearer, OAuth2PasswordRequestForm
from jose import jwt, JWTError
from pydantic import BaseModel
from pymongo import MongoClient
import bcrypt
import uvicorn
import nest_asyncio

SECRET_KEY = "mysecretkey"
ALGORITHM = "HS256"

client = MongoClient("mongodb://localhost:27017")
db = client["propertyDB"]
users = db["users"]
properties = db["properties"]

app = FastAPI()
oauth2_scheme = OAuth2PasswordBearer(tokenUrl="token")

class User(BaseModel):
    email: str
    password: str

class Property(BaseModel):
    title: str
    description: str
    price: float
    location: str
    type: str
    bedrooms: int
    bathrooms: int
    size: float
    amenities: list

def create_token(data: dict):
    return jwt.encode(data, SECRET_KEY, algorithm=ALGORITHM)

def verify_token(token: str):
    try:
        payload = jwt.decode(token, SECRET_KEY, algorithms=[ALGORITHM])
        return payload.get("sub")
    except JWTError:
        return None

def get_current_user(token: str = Depends(oauth2_scheme)):
    user_email = verify_token(token)
    if not user_email:
        raise HTTPException(status_code=401, detail="Invalid token")
    return user_email

@app.post("/register")
def register(user: User):
    if users.find_one({"email": user.email}):
        raise HTTPException(status_code=400, detail="User exists")
    hashed_pw = bcrypt.hashpw(user.password.encode(), bcrypt.gensalt())
    users.insert_one({"email": user.email, "password": hashed_pw})
    return {"msg": "User created"}

@app.post("/token")
def login(form_data: OAuth2PasswordRequestForm = Depends()):
    user = users.find_one({"email": form_data.username})
    if not user or not bcrypt.checkpw(form_data.password.encode(), user["password"]):
        raise HTTPException(status_code=401, detail="Invalid credentials")
    token = create_token({"sub": user["email"]})
    return {"access_token": token, "token_type": "bearer"}

@app.post("/properties")
def add_property(prop: Property, user_email: str = Depends(get_current_user)):
    properties.insert_one({**prop.dict(), "createdBy": user_email})
    return {"msg": "Property added"}

@app.get("/properties")
def get_properties():
    return list(properties.find({}, {"_id": 0}))

@app.delete("/properties/{title}")
def delete_property(title: str, user_email: str = Depends(get_current_user)):
    result = properties.delete_one({"title": title, "createdBy": user_email})
    if result.deleted_count == 0:
        raise HTTPException(status_code=403, detail="Unauthorized or not found")
    return {"msg": "Deleted"}

# %%
# !ngrok config add-authtoken 2xl3YRPjsjGLChy4ahmjS6kOQ48_79sF8PqdRo99G7mmLQtd1
# Out:
# Downloading ngrok ...
# Downloading ngrok: 0%
# Downloading ngrok: 1%
# Downloading ngrok: 2%
# Downloading ngrok: 3%
# Downloading ngrok: 4%
# Downloading ngrok: 5%
# Downloading ngrok: 6%
# Downloading ngrok: 7%
# Downloading ngrok: 8%
# Downloading ngrok: 9%
# Downloading ngrok: 10%
# Downloading ngrok: 11%
# Downloading ngrok: 12%
# Downloading ngrok: 13%
# Downloading ngrok: 14%
# Downloading ngrok: 15%
# Downloading ngrok: 16%
# Downloading ngrok: 17%
# Downloading ngrok: 18%
# Downloading ngrok: 19%
# Downloading ngrok: 20%
# Downloading ngrok: 21%
# Downloading ngrok: 22%
# Downloading ngrok: 23%
# Downloading ngrok: 24%
# Downloading ngrok: 25%
# Downloading ngrok: 26%
# Downloading ngrok: 27%
# Downloading ngrok: 28%
# Downloading ngrok: 29%
# Downloading ngrok: 30%
# Downloading ngrok: 31%
# Downloading ngrok: 32%
# Downloading ngrok: 33%
# Downloading ngrok: 34%
# Downloading ngrok: 35%
# Downloading ngrok: 36%
# Downloading ngrok: 37%
# Downloading ngrok: 38%
# Downloading ngrok: 39%
# Downloading ngrok: 40%
# Downloading ngrok: 41%
# Downloading ngrok: 42%
# Downloading ngrok: 43%
# Downloading ngrok: 44%
# Downloading ngrok: 45%
# Downloading ngrok: 46%
# Downloading ngrok: 47%
# Downloading ngrok: 48%
# Downloading ngrok: 49%
# Downloading ngrok: 50%
# Downloading ngrok: 51%
# Downloading ngrok: 52%
# Downloading ngrok: 53%
# Downloading ngrok: 54%
# Downloading ngrok: 55%
# Downloading ngrok: 56%
# Downloading ngrok: 57%
# Downloading ngrok: 58%
# Downloading ngrok: 59%
# Downloading ngrok: 60%
# Downloading ngrok: 61%
# Downloading ngrok: 62%
# Downloading ngrok: 63%
# Downloading ngrok: 64%
# Downloading ngrok: 65%
# Downloading ngrok: 66%
# Downloading ngrok: 67%
# Downloading ngrok: 68%
# Downloading ngrok: 69%
# Downloading ngrok: 70%
# Downloading ngrok: 71%
# Downloading ngrok: 72%
# Downloading ngrok: 73%
# Downloading ngrok: 74%
# Downloading ngrok: 75%
# Downloading ngrok: 76%
# Downloading ngrok: 77%
# Downloading ngrok: 78%
# Downloading ngrok: 79%
# Downloading ngrok: 80%
# Downloading ngrok: 81%
# Downloading ngrok: 82%
# Downloading ngrok: 83%
# Downloading ngrok: 84%
# Downloading ngrok: 85%
# Downloading ngrok: 86%
# Downloading ngrok: 87%
# Downloading ngrok: 88%
# Downloading ngrok: 89%
# Downloading ngrok: 90%
# Downloading ngrok: 91%
# Downloading ngrok: 92%
# Downloading ngrok: 93%
# Downloading ngrok: 94%
# Downloading ngrok: 95%
# Downloading ngrok: 96%
# Downloading ngrok: 97%
# Downloading ngrok: 98%
# Downloading ngrok: 99%
# Downloading ngrok: 100%
#
# Installing ngrok ...
#
# Authtoken saved to configuration file: C:\Users\DELL\AppData\Local/ngrok/ngrok.yml

# %%
from pyngrok import ngrok
import nest_asyncio
import uvicorn

nest_asyncio.apply()

public_url = ngrok.connect(8000)
print("Public URL:", public_url)

uvicorn.run(app, host="0.0.0.0", port=8000)
